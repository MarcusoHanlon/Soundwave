# %%
import pandas as pd
import numpy as np
import string

# %% [markdown]
# #Lets Do Some Data Analysis
#
# 1 - Import Data
#
# 2 - Compute Summary Statistics
#
# 2 - Carry out some Manipulation
#
# 4 - Visualize

# %%
df = pd.read_excel("df_vol.xlsx")

# %%
df.rename(columns=lambda x: '{}'.format('_'.join([y.strip(string.punctuation) for y in x.lower().split()])), inplace=True)

df.head().T
# Out:
#                                                                                        0  \
# volunteer_id                                                             00Q2000000E7wXL
# create_date                                                          2009-11-09 00:00:00
# how_long_do_you_wish_to_volunteer_for                                                NaN
# age_group                                                                          36-49
# why_do_you_want_to_volunteer_now                                 Recently made redundant
# volunteer_status                                                              Registered
# method_of_contact_with_volunteer                                                     NaN
# face_to_face                                                                         NaN
# gender                                                                              Male
# ...

# %%
from collections import Counter
myDict=Counter(df.volunteer_bureau)
myDict
# Out:
# Counter({u'Dublin City': 19927, u'South Dublin County': 11069, u'Cork': 10561, u'Galway': 9626, u'Fingal': 5574, u'Dun Laoghaire/Rathdown': 4891, u'Kildare': 4323, u'Wicklow': 4018, u'Louth': 4009, u'Carlow': 3517, u'Limerick': 3086, u'Kerry': 3066, u'Meath': 2893, u'Mayo': 2457, u'Sligo': 2384, u'Donegal': 2255, u'Westmeath': 2208, u'South Tipperary': 1736, u'Clare': 1491, u'Monaghan': 1190, u'Longford': 915, u'Offaly': 502, u'Laois': 331, u'Volunteer Ireland': 293, u'Volunteer Centres Ireland': 237, u'Wexford': 179, u'Dublin - General': 168, u'Give it a Swirl Day 2008': 64, u'Leitrim': 54, nan: 5, u'Waterford': 3, u'Yes': 2, u'DunLaoire': 1})
