# %%
import pandas as pd
import json

data = json.dumps([{
"_id": 11,
"claimToFame": "Send me some tunes...or your GitHub!",
"commentCount": 230,
"coverImage": "img.jpg",
"currentLanguage": "en-GB",
"dateOfBirth": "07/29/1982",
"email": "l@gmail.com",
"facebookDetails":    {
        "accessToken": "123",
        "facebookId": "123"
    }
,
"facebookId": 1,
"firstName": "David",
"followerCount": 422403,
"following": False,
"followingCount": 253,
"googleDetails": 
    {
        "googleId": "111411986454983058357",
        "accessToken": "123"
    }
}], separators=(',',':'))

pd.read_json(data)
# Out:
#    _id                           claimToFame  commentCount coverImage  \
# 0   11  Send me some tunes...or your GitHub!           230    img.jpg
#
#   currentLanguage dateOfBirth        email  \
# 0           en-GB  07/29/1982  l@gmail.com
#
#                                    facebookDetails  facebookId firstName  \
# 0  {u'facebookId': u'123', u'accessToken': u'123'}           1     David
#
#    followerCount following  followingCount  \
# 0         422403     False             253
#
#                                        googleDetails
# 0  {u'googleId': u'111411986454983058357', u'acce...

# %%
from pprint import pprint

with open('user.json') as data_file:    
    data = json.load(data_file)
data1=json.dumps([data],separators=(',',':'))
pd.read_json(data1)
# Out:
#        _id                           claimToFame  commentCount coverImage  \
# 0  XXXXX-1  Send me some tunes...or your GitHub!           230    img.jpg
#
#   currentLanguage dateOfBirth              email  \
# 0           en-GB  07/29/1982  lynchdt@gmail.com
#
#                                      facebookDetails  facebookId firstName  \
# 0  {u'facebookId': u'XXXXX', u'accessToken': u'XX...           1     David
#
#      ...                          humdingerId     image  lastName  \
# 0    ...     1032924028d14f647998a3418df70429  img2_jpg     Lynch
#
#                   lastUpdated                 memberSince nameSortKey   place  \
# 0  2015-05-07T13: 22: 51.132Z  2013-03-19T14: 57: 38.052Z  davidlynch  Dublin
#
#   playCount signupPlatform                                     twitterDetails
# 0     13261            iOS  {u'tokenSecret': u'XXX', u'twitterScreenName':...
#
# [1 rows x 28 columns]
